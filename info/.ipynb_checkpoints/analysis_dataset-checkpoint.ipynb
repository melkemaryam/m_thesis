# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("file:////Users/Hannah1/Downloads/all-the-news-2-1.csv")

# %%
df.head()
# Out:
#                   date  year  month  day       author  \
# 0  2016-12-09 18:31:00  2016   12.0    9  Lee Drutman
# 1  2016-10-07 21:26:46  2016   10.0    7  Scott Davis
# 2  2018-01-26 00:00:00  2018    1.0   26          NaN
# 3  2019-06-27 00:00:00  2019    6.0   27          NaN
# 4  2016-01-27 00:00:00  2016    1.0   27          NaN
#
#                                                title  \
# 0  We should take concerns about the health of li...
# 1  Colts GM Ryan Grigson says Andrew Luck's contr...
# 2       Trump denies report he ordered Mueller fired
# 3  France's Sarkozy reveals his 'Passions' but in...
# 4  Paris Hilton: Woman In Black For Uncle Monty's...
#
#                                              article  \
# 0  This post is part of Polyarchy, an independent...
# 1   The Indianapolis Colts made Andrew Luck the h...
# 2  DAVOS, Switzerland (Reuters) - U.S. President ...
# 3  PARIS (Reuters) - Former French president Nico...
# 4  Paris Hilton arrived at LAX Wednesday dressed ...
#
#                                                  url     section  \
# 0  https://www.vox.com/polyarchy/2016/12/9/138983...         NaN
# 1  https://www.businessinsider.com/colts-gm-ryan-...         NaN
# 2  https://www.reuters.com/article/us-davos-meeti...       Davos
# 3  https://www.reuters.com/article/france-politic...  World News
# 4  https://www.tmz.com/2016/01/27/paris-hilton-mo...         NaN
#
#         publication
# 0               Vox
# 1  Business Insider
# 2           Reuters
# 3           Reuters
# 4               TMZ

# %%
# Shape of the dataset
print ("The shape of the dataset : ", df.shape)
# Out:
# The shape of the dataset :  (2688878, 10)

# %%
# !pip3 install wordcloud
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp38-cp38-macosx_10_9_x86_64.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.6/159.6 kB 809.4 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: pillow in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: numpy>=1.6.1 in /Users/Hannah1/Library/Python/3.8/lib/python/site-packages (from wordcloud) (1.24.2)
# Requirement already satisfied: matplotlib in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: six>=1.5 in /Users/Hannah1/Library/Python/3.8/lib/python/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.15.0)
# Installing collected packages: wordcloud
#   WARNING: The script wordcloud_cli is installed in '/Users/Hannah1/Library/Python/3.8/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   NOTE: The current PATH contains path(s) starting with `~`, which may not be expanded by all applications.
# Successfully installed wordcloud-1.9.2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: pip3 install --upgrade pip

# %%
from statistics import mean
from heapq import nlargest
#from wordcloud import WordCloud
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Countplot shows the distribution of Publication
plt.rcParams['figure.figsize'] = [15, 8]
sns.set(font_scale = 1.2, style = 'darkgrid')
sns_year = sns.countplot(x=df['publication'], color = 'darkcyan')
plt.xticks(rotation=45)
sns_year.set(xlabel = "Publication", ylabel = "Count", title = "Distribution of Publication according")
# Out:
# [Text(0.5, 0, 'Publication'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Distribution of Publication according')]

# %%
# Years
df['year'].value_counts()
# Out:
# 2019    655456
# 2017    640493
# 2016    604511
# 2018    553588
# 2020    234830
# Name: year, dtype: int64

# %%
# Countplot shows the distribution of the articles according to the year
plt.rcParams['figure.figsize'] = [15, 8]
sns.set(font_scale = 1.2, style = 'whitegrid')
sns_year = sns.countplot(x=df['year'], color = 'darkcyan')
sns_year.set(xlabel = "Year", ylabel = "Count", title = "Distribution of the articles according to the year")
# Out:
# [Text(0.5, 0, 'Year'),
#  Text(0, 0.5, 'Count'),
#  Text(0.5, 1.0, 'Distribution of the articles according to the year')]

# %%
# Authors
df['author'].value_counts()
# Out:
# WIRED Staff                           15815
# Field Level Media                      7930
# Associated Press                       7428
# John Bowden                            7021
# The Associated Press                   6344
#                                       ...
# Ceci Connolly, opinion contributor        1
# Trey Cowan, opinion contributor           1
# Bernadette Hobson                         1
# Jeff Broin, opinion contributor           1
# Isabel Ling                               1
# Name: author, Length: 138546, dtype: int64

# %%
# Countplot shows the distribution of author
plt.rcParams['figure.figsize'] = [15, 15]
sns.set(font_scale = 1, style = 'whitegrid')
df_author = df.author.value_counts().head(80)

sns.barplot(x=df_author, y=df_author.index)
sns_year.set(xlabel = "count", ylabel = "author", title = "the most freq author")
# Out:
# [Text(0.5, 29.0, 'count'),
#  Text(29.0, 0.5, 'author'),
#  Text(0.5, 1.0, 'the most freq author')]

# %%
pip install "jupyterlab>=3" "ipywidgets>=7.6"
# Out:
# Collecting jupyterlab>=3
#   Downloading jupyterlab-4.0.2-py3-none-any.whl (9.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 2.0 MB/s eta 0:00:0000:0100:01
# Collecting ipywidgets>=7.6
#   Downloading ipywidgets-8.0.6-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Collecting jupyter-lsp>=2.0.0
#   Downloading jupyter_lsp-2.2.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: jupyter-core in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jupyterlab>=3) (4.11.1)
# Collecting notebook-shim>=0.2
#   Downloading notebook_shim-0.2.3-py3-none-any.whl (13 kB)
# Collecting tomli
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting jupyter-server<3,>=2.4.0
#   Downloading jupyter_server-2.6.0-py3-none-any.whl (375 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.0/375.0 kB 2.7 MB/s eta 0:00:0000:0100:01
# Collecting async-lru>=1.0.0
#   Downloading async_lru-2.0.2-py3-none-any.whl (5.7 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jupyterlab>=3) (3.1.2)
# Requirement already satisfied: ipykernel in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jupyterlab>=3) (6.15.2)
# Requirement already satisfied: traitlets in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jupyterlab>=3) (5.3.0)
# Requirement already satisfied: packaging in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jupyterlab>=3) (21.3)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jupyterlab>=3) (6.2)
# Collecting jupyterlab-server<3,>=2.19.0
#   Downloading jupyterlab_server-2.23.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting jupyterlab-widgets~=3.0.7
#   Downloading jupyterlab_widgets-3.0.7-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.2/198.2 kB 1.5 MB/s eta 0:00:0000:01
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipywidgets>=7.6) (8.5.0)
# Collecting widgetsnbextension~=4.0.7
#   Downloading widgetsnbextension-4.0.7-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 2.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from async-lru>=1.0.0->jupyterlab>=3) (4.4.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipykernel->jupyterlab>=3) (1.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipykernel->jupyterlab>=3) (0.1.6)
# Requirement already satisfied: pyzmq>=17 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipykernel->jupyterlab>=3) (23.2.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipykernel->jupyterlab>=3) (7.3.5)
# Requirement already satisfied: appnope in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipykernel->jupyterlab>=3) (0.1.3)
# Requirement already satisfied: psutil in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipykernel->jupyterlab>=3) (5.9.2)
# Requirement already satisfied: nest-asyncio in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipykernel->jupyterlab>=3) (1.5.5)
# Requirement already satisfied: decorator in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6) (5.1.1)
# Requirement already satisfied: pickleshare in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6) (3.0.31)
# Requirement already satisfied: stack-data in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6) (0.5.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6) (0.18.1)
# Requirement already satisfied: backcall in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6) (4.8.0)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.6) (2.13.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab>=3) (2.1.1)
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting websocket-client
#   Downloading websocket_client-1.6.1-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting nbconvert>=6.4.4
#   Downloading nbconvert-7.6.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Collecting jupyter-core
#   Downloading jupyter_core-5.3.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.7/93.7 kB 2.1 MB/s eta 0:00:0000:01
# Collecting send2trash
#   Downloading Send2Trash-1.8.2-py3-none-any.whl (18 kB)
# Collecting traitlets
#   Downloading traitlets-5.9.0-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.4/117.4 kB 2.6 MB/s eta 0:00:00a 0:00:01
# Collecting pyzmq>=17
#   Downloading pyzmq-25.1.0-cp310-cp310-macosx_10_15_universal2.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 2.0 MB/s eta 0:00:0000:0100:01
# Collecting prometheus-client
#   Downloading prometheus_client-0.17.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.0 MB/s eta 0:00:00
# Collecting argon2-cffi
#   Downloading argon2_cffi-21.3.0-py3-none-any.whl (14 kB)
# Collecting overrides
#   Downloading overrides-7.3.1-py3-none-any.whl (17 kB)
# Collecting terminado>=0.8.3
#   Downloading terminado-0.17.1-py3-none-any.whl (17 kB)
# Collecting anyio>=3.1.0
#   Downloading anyio-3.7.0-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Collecting jupyter-client>=6.1.12
#   Downloading jupyter_client-8.3.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 1.7 MB/s eta 0:00:0000:01
# Collecting jupyter-events>=0.6.0
#   Downloading jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Collecting nbformat>=5.3.0
#   Downloading nbformat-5.9.0-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 2.3 MB/s eta 0:00:00
# Collecting platformdirs>=2.5
#   Downloading platformdirs-3.8.0-py3-none-any.whl (16 kB)
# Collecting jsonschema>=4.17.3
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.28 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.19.0->jupyterlab>=3) (2.28.1)
# Collecting babel>=2.10
#   Downloading Babel-2.12.1-py3-none-any.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 3.0 MB/s eta 0:00:0000:010:01
# Collecting json5>=0.9.0
#   Downloading json5-0.9.14-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from packaging->jupyterlab>=3) (3.0.9)
# Collecting exceptiongroup
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab>=3) (3.4)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.6) (0.8.3)
# Collecting attrs>=17.4.0
#   Downloading attrs-23.1.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 632.3 kB/s eta 0:00:00 0:00:01
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.19.3-cp310-cp310-macosx_10_9_universal2.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 1.7 MB/s eta 0:00:0000:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyterlab>=3) (2.8.2)
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Collecting pyyaml>=5.3
#   Downloading PyYAML-6.0-cp310-cp310-macosx_10_9_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.6/197.6 kB 3.2 MB/s eta 0:00:0000:01
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Collecting beautifulsoup4
#   Downloading beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.0/143.0 kB 1.8 MB/s eta 0:00:00a 0:00:01
# Collecting defusedxml
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Collecting tinycss2
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting nbclient>=0.5.0
#   Downloading nbclient-0.8.0-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 2.2 MB/s eta 0:00:00:00:01
# Collecting pandocfilters>=1.4.1
#   Using cached pandocfilters-1.5.0-py2.py3-none-any.whl (8.7 kB)
# Collecting mistune<4,>=2.0.3
#   Downloading mistune-3.0.1-py3-none-any.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 1.2 MB/s eta 0:00:00
# Collecting bleach!=5.0.0
#   Downloading bleach-6.0.0-py3-none-any.whl (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 3.4 MB/s eta 0:00:00a 0:00:01
# Collecting jupyterlab-pygments
#   Downloading jupyterlab_pygments-0.2.2-py2.py3-none-any.whl (21 kB)
# Collecting fastjsonschema
#   Downloading fastjsonschema-2.17.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.6) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython>=6.1.0->ipywidgets>=7.6) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.19.0->jupyterlab>=3) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.19.0->jupyterlab>=3) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server<3,>=2.19.0->jupyterlab>=3) (2022.9.24)
# Collecting argon2-cffi-bindings
#   Downloading argon2_cffi_bindings-21.2.0-cp38-abi3-macosx_10_9_universal2.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: asttokens in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6) (2.0.8)
# Requirement already satisfied: pure-eval in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6) (0.2.2)
# Requirement already satisfied: executing in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.6) (1.0.0)
# Collecting webencodings
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: six>=1.9.0 in /usr/local/Cellar/six/1.16.0_2/lib/python3.10/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=3) (1.16.0)
# Collecting webcolors>=1.11
#   Downloading webcolors-1.13-py3-none-any.whl (14 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting uri-template
#   Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab>=3) (1.15.1)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.4.1-py3-none-any.whl (36 kB)
# Requirement already satisfied: pycparser in /usr/local/Cellar/ipython/8.5.0/libexec/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->jupyterlab>=3) (2.21)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: webencodings, json5, fastjsonschema, widgetsnbextension, websocket-client, webcolors, uri-template, traitlets, tomli, tinycss2, terminado, soupsieve, sniffio, send2trash, rfc3986-validator, rfc3339-validator, pyzmq, pyyaml, python-json-logger, pyrsistent, prometheus-client, platformdirs, pandocfilters, overrides, mistune, jupyterlab-widgets, jupyterlab-pygments, jsonpointer, fqdn, exceptiongroup, defusedxml, bleach, babel, attrs, async-lru, jupyter-server-terminals, jupyter-core, jsonschema, beautifulsoup4, arrow, argon2-cffi-bindings, anyio, nbformat, jupyter-client, isoduration, argon2-cffi, nbclient, nbconvert, jupyter-events, ipywidgets, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.3.0
#     Uninstalling traitlets-5.3.0:
#       Successfully uninstalled traitlets-5.3.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.1
#     Uninstalling pyzmq-23.2.1:
#       Successfully uninstalled pyzmq-23.2.1
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter_core 4.11.1
#     Uninstalling jupyter_core-4.11.1:
#       Successfully uninstalled jupyter_core-4.11.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.3.5
#     Uninstalling jupyter_client-7.3.5:
#       Successfully uninstalled jupyter_client-7.3.5
# Successfully installed anyio-3.7.0 argon2-cffi-21.3.0 argon2-cffi-bindings-21.2.0 arrow-1.2.3 async-lru-2.0.2 attrs-23.1.0 babel-2.12.1 beautifulsoup4-4.12.2 bleach-6.0.0 defusedxml-0.7.1 exceptiongroup-1.1.1 fastjsonschema-2.17.1 fqdn-1.5.1 ipywidgets-8.0.6 isoduration-20.11.0 json5-0.9.14 jsonpointer-2.4 jsonschema-4.17.3 jupyter-client-8.3.0 jupyter-core-5.3.1 jupyter-events-0.6.3 jupyter-lsp-2.2.0 jupyter-server-2.6.0 jupyter-server-terminals-0.4.4 jupyterlab-4.0.2 jupyterlab-pygments-0.2.2 jupyterlab-server-2.23.0 jupyterlab-widgets-3.0.7 mistune-3.0.1 nbclient-0.8.0 nbconvert-7.6.0 nbformat-5.9.0 notebook-shim-0.2.3 overrides-7.3.1 pandocfilters-1.5.0 platformdirs-3.8.0 prometheus-client-0.17.0 pyrsistent-0.19.3 python-json-logger-2.0.7 pyyaml-6.0 pyzmq-25.1.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.2 sniffio-1.3.0 soupsieve-2.4.1 terminado-0.17.1 tinycss2-1.2.1 tomli-2.0.1 traitlets-5.9.0 uri-template-1.3.0 webcolors-1.13 webencodings-0.5.1 websocket-client-1.6.1 widgetsnbextension-4.0.7
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: /usr/local/Cellar/ipython/8.5.0/libexec/bin/python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
